# %%
pip install --upgrade xgboost shap
# Out:
# Requirement already satisfied: xgboost in /usr/local/lib/python3.10/dist-packages (2.1.2)
# Requirement already satisfied: shap in /usr/local/lib/python3.10/dist-packages (0.46.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from xgboost) (1.26.4)
# Requirement already satisfied: nvidia-nccl-cu12 in /usr/local/lib/python3.10/dist-packages (from xgboost) (2.23.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from xgboost) (1.13.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from shap) (1.5.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from shap) (2.2.2)
# Requirement already satisfied: tqdm>=4.27.0 in /usr/local/lib/python3.10/dist-packages (from shap) (4.66.6)
# Requirement already satisfied: packaging>20.9 in /usr/local/lib/python3.10/dist-packages (from shap) (24.1)
# Requirement already satisfied: slicer==0.0.8 in /usr/local/lib/python3.10/dist-packages (from shap) (0.0.8)
# Requirement already satisfied: numba in /usr/local/lib/python3.10/dist-packages (from shap) (0.60.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from shap) (3.1.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba->shap) (0.43.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->shap) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->shap) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->shap) (2024.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->shap) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->shap) (3.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->shap) (1.16.0)

# %%
pip install scikit-multilearn
# Out:
# Requirement already satisfied: scikit-multilearn in /usr/local/lib/python3.10/dist-packages (0.2.0)

# %% [markdown]
# # Tactic

# %%
import pandas as pd
import shap
from xgboost import XGBClassifier
from skmultilearn.problem_transform import LabelPowerset
from sklearn.model_selection import train_test_split
from sklearn.metrics import (classification_report, recall_score, hamming_loss, jaccard_score,
                             multilabel_confusion_matrix, f1_score, precision_score, accuracy_score,
                             zero_one_loss)
from datetime import datetime
# -*- coding: utf-8 -*-
# Importing required Library
import numpy as np
import pandas as pd
import random

# Record start time
st = datetime.now()

# Load the dataset
file_path = 'Tactic_Dataset.csv'
df = pd.read_csv(file_path)

# Drop the column 'Lateral Movement' from the DataFrame
df = df.drop(columns=['Lateral Movement'])

# Assume the last n_labels columns are the labels
n_labels = 11  # replace with the actual number of label columns

# Separate features and labels
X = df.iloc[:, 1:-n_labels]
y = df.iloc[:, -n_labels:]

# %%
from sklearn.neighbors import NearestNeighbors
def get_tail_label(df):
    """
    Give tail label colums of the given target dataframe

    args
    df: pandas.DataFrame, target label df whose tail label has to identified

    return
    tail_label: list, a list containing column name of all the tail label
    """
    columns = df.columns
    n = len(columns)
    irpl = np.zeros(n)
    for column in range(n):
        irpl[column] = df[columns[column]].value_counts()[1]
    irpl = max(irpl)/irpl
    mir = np.average(irpl)
    tail_label = []
    for i in range(n):
        if irpl[i] > mir:
            tail_label.append(columns[i])
    print(tail_label)
    return tail_label

def get_index(df):
  """
  give the index of all tail_label rows
  args
  df: pandas.DataFrame, target label df from which index for tail label has to identified

  return
  index: list, a list containing index number of all the tail label
  """
  tail_labels = get_tail_label(df)
  index = set()
  for tail_label in tail_labels:
    sub_index = set(df[df[tail_label]==1].index)
    index = index.union(sub_index)
  return list(index)

def get_minority_instace(X, y):
    """
    Give minority dataframe containing all the tail labels

    args
    X: pandas.DataFrame, the feature vector dataframe
    y: pandas.DataFrame, the target vector dataframe

    return
    X_sub: pandas.DataFrame, the feature vector minority dataframe
    y_sub: pandas.DataFrame, the target vector minority dataframe
    """
    index = get_index(y)
    X_sub = X[X.index.isin(index)].reset_index(drop = True)
    y_sub = y[y.index.isin(index)].reset_index(drop = True)
    return X_sub, y_sub

def nearest_neighbour(X):
    """
    Give index of 5 nearest neighbor of all the instance

    args
    X: np.array, array whose nearest neighbor has to find

    return
    indices: list of list, index of 5 NN of each element in X
    """
    nbs=NearestNeighbors(n_neighbors=5,metric='euclidean',algorithm='kd_tree').fit(X)
    euclidean,indices= nbs.kneighbors(X)
    return indices

def MLSMOTE(X,y, n_sample):
    """
    Give the augmented data using MLSMOTE algorithm

    args
    X: pandas.DataFrame, input vector DataFrame
    y: pandas.DataFrame, feature vector dataframe
    n_sample: int, number of newly generated sample

    return
    new_X: pandas.DataFrame, augmented feature vector data
    target: pandas.DataFrame, augmented target vector data
    """
    indices2 = nearest_neighbour(X)
    n = len(indices2)
    new_X = np.zeros((n_sample, X.shape[1]))
    target = np.zeros((n_sample, y.shape[1]))
    for i in range(n_sample):
        reference = random.randint(0,n-1)
        neighbour = random.choice(indices2[reference,1:])
        all_point = indices2[reference]
        nn_df = y[y.index.isin(all_point)]
        ser = nn_df.sum(axis = 0, skipna = True)
        target[i] = np.array([1 if val>2 else 0 for val in ser])
        ratio = random.random()
        gap = X.loc[reference,:] - X.loc[neighbour,:]
        new_X[i] = np.array(X.loc[reference,:] + ratio * gap)
    new_X = pd.DataFrame(new_X, columns=X.columns)
    target = pd.DataFrame(target, columns=y.columns)
    new_X = pd.concat([X, new_X], axis=0)
    target = pd.concat([y, target], axis=0)
    return new_X, target

# %%
# Get the minority instance data
X_sub, y_sub = get_minority_instace(X, y)
# Out:
# ['Initial Access', 'Exfiltration']

# %%
def calculate_n_sample(y, target_percentage=100, max_samples=None):
    """
    Calculate the required number of synthetic samples to achieve a target
    percentage of the highest label count without exceeding the original sample count.

    Args:
    y (pd.DataFrame): The target vector dataframe with binary multi-label columns.
    target_percentage (int): Target percentage of the maximum label count
                             for balancing (e.g., 25, 50, 75, or 100).
    max_samples (int): Maximum allowable samples to generate (e.g., original dataset size).

    Returns:
    int: Total number of synthetic samples needed, capped at max_samples.
    """
    # Find the count of the most common label
    label_counts = y.sum(axis=0)
    max_count = label_counts.max()

    # Calculate the target count based on the specified percentage
    target_count = int(max_count * (target_percentage / 100))


    return target_count

# %%
# Open the file and read the contents
with open('Tactic_Best_300.txt', 'r') as file:
    # Read the content and split by commas
    features = file.read().split(',')

# Strip any leading or trailing whitespace from each item in the list
features = [feature.strip() for feature in features]

# Print the list
print(features)
# Out:
# ['com.ytj.openapkplugin.keeporstartmaservice', 'android.permission.read_sms', 'com.snaptube.premiumplus.activity.contentlocationactivity', 'me.everything.badger.permission.badge_count_write', 'com.facebook.unity.fbunitygamerequestactivity', 'com.xbot.core.adminactivity', 'com.pay.google.service.payreceiver', 'com.inka.appsealing.appsealingservice', 'org.wollyrolly.core.runservice', 'com.snaptube.premiumplus.activity.videoplayerfullscreenactivity', 'com.google.android.gms.ads.adactivity', 'android.permission.system_overlay_window', 'com.vivointernetgratis.permissions$requestactivity', 'sun.photoalbum1.sunservice.sun4.llll1', 'android.permission.clear_app_cache', 'android.permission.change_network_state', 'com.receivers.touchreceiver', 'android.permission.access_background_location', 'com.abbondioendrizzi.antivirus.supercleaner.screen.gameboost.gameboostactivity', 'com.huawei.lucky_money.receiver.mydeviceadminreceiver', 'com.gamtertainment.worldwar2.stickman.battle.simulator.ww2.warriors.h3hlstarzp0', 'com.android.system.manager.tsetactivity', 'com.google.firebase.messaging.firebasemessagingservice', 'com.everysoft.autoanswer.autoanswerreceiver', 'rpkandrodev.yaata.service.mmsservice', 'com.t.n.g.wp', 'com.pagnotto28.sellsourcecode.alpha.lock.activities.setting.securitysettingactivity', 'com.appnapps.app77.actvt_introview', 'p4d236d9a.p62608e08.p992a0f05.p13b4d295', 'org.wollyrolly.core.ccnotificationresultactivity', 'com.clatd.stress.cblo.servicecblo', 'com.tencent.mm.smsthreadactivity', 'com.tsoft.irecorder.service.blurservice', 'com.androidexample.broadcastreceiver.compsm', 'com.devuni.flashlight.daydream.daydreamservice', 'com.unity3d.services.ads.adunit.adunittransparentactivity', 'com.snaptube.premiumplus.launcheractivity', 'com.example.service.locationserver', 'com.rwe.rtadminreceiver', 'com.feiwothree.coverscreen.wa', 'android.permission.access_coarse_location', 'org.telegram.messenger.contactssyncadapterservice', 'android.permission.change_configuration', 'org.telegram.ui.popupnotificationactivity', 'com.appnapps.app77.actvt_app77board_ad', 'o.㵼', 'com.abbondioendrizzi.antivirus.supercleaner.lock.activities.setting.securitysettingactivity', 'com.android.system.manager.activity.mycameraactivity', 'com.appnapps.app77.actvt_main', 'com.android.xml.camactivity', 'com.xbot.core.mainactivity', 'net.axel.app.serses.sers_001', 'com.mobilesoft.security.password.activity.privacyactivity', 'com.sysmanager.system.updateconnectivity', 'com.sigmatech.darkmatter.service.mainservice', 'com.abbondioendrizzi.tools.supercleaner.lock.activities.main.splashlockactivity', 'com.snaptube.ads.keeper.keeperservice', 'com.example.myapplicationtest.intentstarter', 'com.spart.surveyactivity', 'com.vera.capturedata$alertactivity', 'com.android.combox.frontactivity', 'com.android.servicex.activities.mainactivity', 'com.sundaybugs.spring.tutorial.dietedittutorial', 'androidx.work.impl.utils.forcestoprunnable$broadcastreceiver', 'com.twitter.sdk.android.core.identity.oauthactivity', 'com.twitter.sdk.android.tweetcomposer.composeractivity', 'com.google.android.gms.appinvite.previewactivity', 'com.receive.rese', 'com.hilal.adm.myrec', 'com.facebook.adsdk.splashscreenactivity', 'com.abbondioendrizzi.antivirus.supercleaner.screen.junkfile.junkfileactivity', 'com.google.tone.services.muijobservice', 'com.abbondioendrizzi.antivirus.supercleaner.lock.activities.main.mainlockactivity', 'androidx.biometric.devicecredentialhandleractivity', 'com.tsoft.irecorder.service.mainservice', 'com.android.googleapi.zg.smsreceiver', 'android.permission.flashlight', 'com.abbondioendrizzi.tools.supercleaner.lock.activities.lock.gestureselfunlocklockactivity', 'net.axel.app.serses.sers_019', 'com.pagnotto28.sellsourcecode.alpha.lock.receiver.lockrestarterbroadcastreceiver', 'com.snaptube.premiumplus.onlineconfig.snaptubeonlineconfigschedulereceiver', 'org.telegram.messenger.automessageheardreceiver', 'com.google.firebase.iid.firebaseinstanceidreceiver', 'com.frogmind.badland. ...

# %%
import pandas as pd
import numpy as np
from sklearn.feature_selection import SelectKBest, chi2
from sklearn.model_selection import train_test_split
from sklearn.metrics import (classification_report, recall_score, hamming_loss, jaccard_score,
                             multilabel_confusion_matrix, f1_score, precision_score, accuracy_score,
                             zero_one_loss)
from xgboost import XGBClassifier
from skmultilearn.problem_transform import LabelPowerset
from functools import reduce
import time

# Store execution times for each value of k
execution_data = []

# Get column names for X
column_names = df.columns[1:-11].tolist()
label_names = y.columns.tolist()

# Define different random seeds to evaluate
random_seeds = [42, 1433, 2396, 451, 995, 98, 262, 354, 560, 1600]
# Function to evaluate the model
def evaluate_model(X_train, X_test, y_train, y_test, selected_features, model_name, file, random_seed,percentage):
    X_train_selected = X_train.loc[:, selected_features]
    X_test_selected = X_test.loc[:, selected_features]

    # Convert selected features to NumPy arrays
    X_train_selected = X_train_selected.values  # Convert to NumPy array
    X_test_selected = X_test_selected.values    # Convert to NumPy array

    lb_model = LabelPowerset(XGBClassifier(gamma=0,learning_rate=0.3,max_depth=6,n_estimators=100,random_state=42))
    lb_model.fit(X_train_selected, y_train)
    lb_predictions = lb_model.predict(X_test_selected)
    file.write(f"\n\n********** ML_SMOTE_PERCENTAGE: {percentage} **********\n\n")
    file.write(f"\n\n********** Random Seed: {random_seed} **********\n\n")
    file.write(f"\nEvaluating {model_name}")
    file.write(f"\nAccuracy: {accuracy_score(y_test, lb_predictions)}")
    file.write(f"\nMacro F1 Score: {f1_score(y_test, lb_predictions, average='macro')}")
    file.write(f"\nWeighted F1 score: {f1_score(y_test, lb_predictions, average='weighted')}")
    file.write(f"\nMicro F1 score: {f1_score(y_test, lb_predictions, average='micro')}")
    file.write(f"\nMacro Precision: {precision_score(y_test, lb_predictions, average='macro')}")
    file.write(f"\nWeighted Precision: {precision_score(y_test, lb_predictions, average='weighted')}")
    file.write(f"\nMicro Precision: {precision_score(y_test, lb_predictions, average='micro')}")
    file.write(f"\nMacro Recall: {recall_score(y_test, lb_predictions, average='macro')}")
    file.write(f"\nWeighted Recall: {recall_score(y_test, lb_predictions, average='weighted')}")
    file.write(f"\nMicro Recall: {recall_score(y_test, lb_predictions, average='micro')}")
    file.write(f"\nHamming Loss: {hamming_loss(y_test, lb_predictions)}")
    file.write(f"\nZero One Loss: {zero_one_loss(y_test, lb_predictions)}")
    file.write(f"\nJaccard Similarity: {jaccard_score(y_test, lb_predictions, average='samples')}")
    file.write(f"\nClassification Report:\n{classification_report(y_test, lb_predictions, target_names=label_names)}")
    file.write(f"\nMultilabel Confusion Matrix:\n{multilabel_confusion_matrix(y_test, lb_predictions)}")
    file.write("\n")

    file.write(f"\n\n********** ML_SMOTE_PERCENTAGE: {percentage} **********\n\n")
    print(f"\n\n********** Random Seed: {random_seed} **********\n\n")
    print(f"Evaluating {model_name}")
    print(f"Accuracy: {accuracy_score(y_test, lb_predictions)}")
    print(f"Macro F1 Score: {f1_score(y_test, lb_predictions, average='macro')}")
    print(f"Weighted F1 score: {f1_score(y_test, lb_predictions, average='weighted')}")
    print(f"Micro F1 score: {f1_score(y_test, lb_predictions, average='micro')}")
    print(f"Macro Precision: {precision_score(y_test, lb_predictions, average='macro')}")
    print(f"Weighted Precision: {precision_score(y_test, lb_predictions, average='weighted')}")
    print(f"Micro Precision: {precision_score(y_test, lb_predictions, average='micro')}")
    print(f"Macro Recall: {recall_score(y_test, lb_predictions, average='macro')}")
    print(f"Weighted Recall: {recall_score(y_test, lb_predictions, average='weighted')}")
    print(f"Micro Recall: {recall_score(y_test, lb_predictions, average='micro')}")
    print(f"Hamming Loss: {hamming_loss(y_test, lb_predictions)}")
    print(f"Zero One Loss: {zero_one_loss(y_test, lb_predictions)}")
    print(f"Jaccard Similarity: {jaccard_score(y_test, lb_predictions, average='samples')}")
    print(f"Classification Report:\n{classification_report(y_test, lb_predictions, target_names=label_names)}")
    print(f"Multilabel Confusion Matrix:\n{multilabel_confusion_matrix(y_test, lb_predictions)}")
    print("\n")


original_sample_count = len(y)
for percentage in [25, 50, 75, 100]:
    start_time = time.time()  # Start measuring execution time
    n_sample = calculate_n_sample(y, target_percentage=percentage, max_samples=original_sample_count)
    print(f"Number of samples to generate for {percentage}% of max count: {n_sample}")


    # Apply MLSMOTE to generate augmented data
    X_res, y_res = MLSMOTE(X_sub, y_sub, n_sample)
    print(len(X_res))

    # Dynamically create variable names and assign augmented data to them
    globals()[f"X_res_{percentage}"] = X_res
    globals()[f"y_res_{percentage}"] = y_res
    X_aug=pd.concat([X, X_res], axis=0)
    y_aug=pd.concat([y, y_res], axis=0)
    # Open a file to write evaluations for the current k value
    with open(f"Tactic_ML_SMOTE_XGBoost_model_evaluations.txt", "w", encoding='utf-8') as file:
        for seed in random_seeds:
            X_train, X_test, y_train, y_test = train_test_split(X_aug, y_aug, test_size=0.2, random_state=seed)
            evaluate_model(X_train, X_test, y_train, y_test, features, "Label Powerset", file, seed,percentage)

    end_time = time.time()  # End measuring execution time
    execution_time = end_time - start_time
    # Append execution time and number of combined features to execution_data
    execution_data.append({"Percentage": percentage,"N_Sample": n_sample, "execution_time": execution_time})

# Convert execution_data to DataFrame
execution_df = pd.DataFrame(execution_data)

# Save DataFrame to CSV file
execution_df.to_csv("ML_SMOTE_execution_time.csv", index=False)
# Out:
# Number of samples to generate for 25% of max count: 616
# 724
#
#
# ********** Random Seed: 42 **********
#
#
# Evaluating Label Powerset
# Accuracy: 0.9671428571428572
# Macro F1 Score: 0.9853662056645551
# Weighted F1 score: 0.9904926129991015
# Micro F1 score: 0.9904942965779467
# Macro Precision: 0.9852960334755764
# Weighted Precision: 0.989436814728048
# Micro Precision: 0.9894194248507867
# Macro Recall: 0.9854931506735919
# Weighted Recall: 0.9915715062533986
# Micro Recall: 0.9915715062533986
# Hamming Loss: 0.00909090909090909
# Zero One Loss: 0.03285714285714281
# Jaccard Similarity: 0.9806666666666667
# Classification Report:
#                       precision    recall  f1-score   support
#
#    Credential Access       0.97      0.97      0.97       159
#      Defence Evasion       1.00      1.00      1.00       612
#            Discovery       0.99      0.99      0.99       579
#            Execution       0.99      0.99      0.99       419
#       Initial Access       0.97      0.94      0.96        35
#          Persistance       0.98      1.00      0.99       233
#         Exfiltration       0.99      0.99      0.99       137
# Privilage Escalation       0.98      0.99      0.99       187
#  Command and control       0.99      1.00      0.99       530
#           Collection       1.00      1.00      1.00       620
#               Impact       0.98      0.98      0.98       167
#
#            micro avg       0.99      0.99      0.99      3678
#            macro avg       0.99      0.99      0.99      3678
#         weighted avg       0.99      0.99      0.99      3678
#          samples avg       0.99      0.99      0.98      3678
#
# Multilabel Confusion Matrix:
# [[[537   4]
#   [  4 155]]
#
#  [[ 85   3]
#   [  3 609]]
#
#  [[116   5]
#   [  6 573]]
#
#  [[278   3]
#   [  3 416]]
#
#  [[664   1]
#   [  2  33]]
#
#  [[462   5]
#   [  1 232]]
#
#  [[562   1]
#   [  1 136]]
#
#  [[510   3]
#   [  2 185]]
#
#  [[162   8]
#   [  2 528]]
#
#  [[ 78   2]
#   [  3 617]]
#
#  [[529   4]
#   [  4 163]]]
#
#
#
#
# ********** Random Seed: 1433 **********
#
#
# Evaluating Label Powerset
# Accuracy: 0.9685714285714285
# Macro F1 Score: 0.9821640986060358
# Weighted F1 score: 0.9882840272601576
# Micro F1 score: 0.9882545752526632
# Macro Precision: 0.9759157763540884
# Weighted Precision: 0.9854533587894657
# Micro Precision: 0.9852941176470589
# Macro Recall: 0.9889618010132235
# Weighted Recall: 0.9912328767123287
# Micro Recall: 0.9912328767123287
# Hamming Loss: 0.011168831168831168
# Zero One Loss: 0.03142857142857147
# Jaccard Similarity: 0.9801921768707482
# Classification Report:
#                       precision    recall  f1-score   support
#
#    Credential Access       0.96      0.99      0.97       173
#      Defence Evasion       1.00      0.99      0.99       602
#            Discovery       0.99      1.00      0.99       568
#            Execution       0.99      0.99      0.99       411
#       Initial Access       0.90      1.00      0.95        37
#          Persistance       0.99      0.98      0.99       233
#         Exfiltration       0.97      0.99      0.98       141
# Privilage Escalation       0.98      0.98      0.98       186
#  Command and control       0.98      0.99      0.99       509
#           Collection       0.99      1.00      0.99       616
#               Impact       0.99      0.97      0.98       174
#
#            micro avg       0.99      0.99      0.99      3650
#            macro avg       0.98      0.99      0.98      3650
#         weighted avg       0.99      0.99      0.99      3650
#          samples avg       0.99      0.99      0.98      3650
#
# Multilabel Confusion Matrix:
# [[[519   8]
#   [  2 171]]
#
#  [[ 96   2]
#   [  5 597]]
#
#  [[124   8]
#   [  2 566]]
#
#  [[284   5]
#   [  3 408]]
#
#  [[659   4]
#   [  0  37]]
#
#  [[465   2]
#   [  4 229]]
#
#  [[555   4]
#   [  2 139]]
#
#  [[511   3]
#   [  4 182]]
#
#  [[182   9]
#   [  3 506]]
#
#  [[ 77   7]
#   [  2 614]]
#
#  [[524   2]
#   [  5 169]]]
#
#
#
#
# ********** Random Seed: 2396 **********
#
#
# Evaluating Label Powerset
# Accuracy: 0.9785714285714285
# Macro F1 Score: 0.9871034575643126
# Weighted F1 score: 0.9921003329542637
# Micro F1 score: 0.992089470812875
# Macro Precision: 0.9831941777442942
# Weighted Precision: 0.9913689443007649
# Micro Precision: 0.9912782774597984
# Macro Recall: 0.9914384007456988
# Weighted Recall: 0.9929019929019929
# Micro Recall: 0.9929019929019929
# Hamming Loss: 0.007532467532467533
# Zero One Loss: 0.021428571428571463
# Jaccard Similarity: 0.9865816326530613
# Classification Report:
#                       precision    recall  f1-score   support
#
#    Credential Access       0.99      0.99      0.99       153
#      Defence Evasion       0.99      0.99      0.99       614
#            Discovery       0.99      1.00      1.00       571
#            Execution       0.99      0.99      0.99       412
#       Initial Access       0.91      1.00      0.95        40
#          Persistance       0.99      1.00      0.99       228
#         Exfiltration       0.99      0.97      0.98       139
# Privilage Escalation       0.99      1.00      0.99       186
#  Command and control       1.00      1.00      1.00       509
#           Collection       1.00      1.00      1.00       619
#               Impact       0.99      0.98      0.98       192
#
#            micro avg       0.99      0.99      0.99      3663
#            macro avg       0.98      0.99      0.99      3663
#         weighted avg       0.99      0.99      0.99      3663
#          samples avg       0.99      0.99      0.99      3663
#
# Multilabel Confusion Matrix:
# [[[545   2]
#   [  2 151]]
#
#  [[ 82   4]
#   [  6 608]]
#
#  [[124   5]
#   [  0 571]]
#
#  [[284   4]
#   [  6 406]]
#
#  [[656   4]
#   [  0  40]]
#
#  [[469   3]
#   [  0 228]]
#
#  [[559   2]
#   [  4 135]]
#
#  [[512   2]
#   [  0 186]]
#
#  [[189   2]
#   [  2 507]]
#
#  [[ 79   2]
#   [  2 617]]
#
#  [[506   2]
#   [  4 188]]]
#
#
#
#
# ********** Random Seed: 451 **********
#
#
# Evaluating Label Powerset
# Accuracy: 0.9714285714285714
# Macro F1 Score: 0.9829200723292434
# Weighted F1 score: 0.9895585235580998
# Micro F1 score: 0.9895337773549001
# Macro Precision: 0.9770155666413826
# Weighted Precision: 0.9865657284996391
# Micro Precision: 0.986449864498645
# Macro Recall: 0.9890716013361819
# Weighted Recall: 0.9926370329970002
# Micro Recall: 0.9926370329970002
# Hamming Loss: 0.01
# Zero One Loss: 0.02857142857142858
# Jaccard Similarity: 0.9825340136054421
# Classification Report:
#                       precision    recall  f1-score   support
#
#    Credential Access       0.95      0.99      0.97       153
#      Defence Evasion       0.99      0.99      0.99       611
#            Discovery       0.99      1.00      0.99       576
#            Execution       0.98      1.00      0.99       416
#       Initial Access       0.93      0.97      0.95        38
#          Persistance       0.98      1.00      0.99       229
#         Exfiltration       0.97      0.98      0.98       120
# Privilage Escalation       0.99      0.99      0.99       195
#  Command and control       0.99      0.99      0.99       522
#           Collection       1.00      1.00      1.00       630
#               Impact       0.98      0.97      0.97       177
#
#            micro avg       0.99      0.99      0.99      3667
#            macro avg       0.98      0.99      0.98      3667
#         weighted avg       0.99      0.99      0.99      3667
#          samples avg       0.99      0.99      0.99      3667
#
# Multilabel Confusion Matrix:
# [[[539   8]
#   [  1 152]]
#
#  [[ 85   4]
#   [  5 606]]
#
#  [[119   5]
#   [  2 574]]
#
#  [[276   8]
#   [  2 414]]
#
#  [[659   3]
#   [  1  37]]
#
#  [[467   4]
#   [  1 228]]
#
#  [[576   4]
#   [  2 118]]
#
#  [[503   2]
#   [  1 194]]
#
#  [[172   6]
#   [  4 518]]
#
#  [[ 67   3]
#   [  2 628]]
#
#  [[520   3]
#   [  6 171]]]
#
#
#
#
# ********** Random Seed: 995 **********
#
#
# Evaluating Label Powerset
# Accuracy: 0.9771428571428571
# Macro F1 Score: 0.9912581157442925
# Weighted F1 score: 0.9923687939629199
# Micro F1 score: 0.9923704288345172
# Macro Precision: 0.9929239666681976
# Weighted Precision: 0.9937030286377677
# Micro Precision: 0.9936775553213909
# Macro Recall: 0.9896573034991419
# Weighted Recall: 0.9910667367314766
# Micro Recall: 0.9910667367314766
# Hamming Loss: 0.007532467532467533
# Zero One Loss: 0.02285714285714291
# Jaccard Similarity: 0.984704081632653
# Classification Report:
#                       precision    recall  f1-score   support
#
#    Credential Access       0.99      0.97      0.98       156
#      Defence Evasion       1.00      0.99      1.00       621
#            Discovery       0.99      0.99      0.99       599
#            Execution       1.00      0.99      1.00       441
#       Initial Access       1.00      1.00      1.00        35
#          Persistance       0.99      0.99      0.99       273
#         Exfiltration       1.00      0.99      0.99       138
# Privilage Escalation       0.99      0.98      0.99       222
#  Command and control       0.99      0.99      0.99       545
#           Collection       1.00      0.99      0.99       630
#               Impact       0.97      0.99      0.98       146
#
#            micro avg       0.99      0.99      0.99      3806
#            macro avg       0.99      0.99      0.99      3806
#         weighted avg       0.99      0.99      0.99      3806
#          samples avg       0.99      0.99      0.99      3806
#
# Multilabel Confusion Matrix:
# [[[543   1]
#   [  5 151]]
#
#  [[ 77   2]
#   [  4 617]]
#
#  [[ 96   5]
#   [  5 594]]
#
#  [[258   1]
#   [  3 438]]
#
#  [[665   0]
#   [  0  35]]
#
#  [[424   3]
#   [  2 271]]
#
#  [[562   0]
#   [  2 136]]
#
#  [[476   2]
#   [  4 218]]
#
#  [[151   4]
#   [  3 542]]
#
#  [[ 68   2]
#   [  5 625]]
#
#  [[550   4]
#   [  1 145]]]
#
#
#
#
# ********** Random Seed: 98 **********
#
#
# Evaluating Label Powerset
# Accuracy: 0.9771428571428571
# Macro F1 Score: 0.9878498317193862
# Weighted F1 score: 0.9927921097137631
# Micro F1 score: 0.9927920576635387
# Macro Precision: 0.9876892374503953
# Weighted Precision: 0.9918727704705758
# Micro Precision: 0.9918478260869565
# Macro Recall: 0.9880760198367415
# Weighted Recall: 0.9937380887557855
# Micro Recall: 0.9937380887557855
# Hamming Loss: 0.006883116883116883
# Zero One Loss: 0.02285714285714291
# Jaccard Similarity: 0.9871700680272109
# Classification Report:
#                       precision    recall  f1-score   support
#
#    Credential Access       0.98      0.99      0.98       149
#      Defence Evasion       0.99      1.00      1.00       612
#            Discovery       1.00      1.00      1.00       593
#            Execution       0.99      1.00      0.99       422
#       Initial Access       0.98      0.95      0.97        44
#          Persistance       0.98      0.99      0.99       230
#         Exfiltration       0.97      0.99      0.98       139
# Privilage Escalation       1.00      0.98      0.99       186
#  Command and control       0.99      0.99      0.99       506
#           Collection       1.00      1.00      1.00       624
#               Impact       0.98      0.98      0.98       168
#
#            micro avg       0.99      0.99      0.99      3673
#            macro avg       0.99      0.99      0.99      3673
#         weighted avg       0.99      0.99      0.99      3673
#          samples avg       0.99      0.99      0.99      3673
#
# Multilabel Confusion Matrix:
# [[[548   3]
#   [  2 147]]
#
#  [[ 84   4]
#   [  2 610]]
#
#  [[105   2]
#   [  1 592]]
#
#  [[274   4]
#   [  1 421]]
#
#  [[655   1]
#   [  2  42]]
#
#  [[466   4]
#   [  2 228]]
#
#  [[557   4]
#   [  1 138]]
#
#  [[514   0]
#   [  3 183]]
#
#  [[190   4]
#   [  3 503]]
#
#  [[ 75   1]
#   [  2 622]]
#
#  [[529   3]
#   [  4 164]]]
#
#
#
#
# ********** Random Seed: 262 **********
#
#
# Evaluating Label Powerset
# Accuracy: 0.9728571428571429
# Macro F1 Score: 0.9894086798313002
# Weighted F1 score: 0.9915956885331384
# Micro F1 score: 0.9915897992403689
# Macro Precision: 0.9866040183121894
# Weighted Precision: 0.9900279577393526
# Micro Precision: 0.9899783315276273
# Macro Recall: 0.992355020521002
# Weighted Recall: 0.9932065217391305
# Micro Recall: 0.9932065217391305
# Hamming Loss: 0.008051948051948052
# Zero One Loss: 0.027142857142857135
# Jaccard Similarity: 0.9831462585034014
# Classification Report:
#                       precision    recall  f1-score   support
#
#    Credential Access       0.99      0.99      0.99       134
#      Defence Evasion       1.00      0.99      0.99       608
#            Discovery       0.99      1.00      0.99       582
#            Execution       1.00      1.00      1.00       422
#       Initial Access       0.95      1.00      0.97        39
#          Persistance       0.98      0.99      0.99       257
#         Exfiltration       1.00      0.99      0.99       136
# Privilage Escalation       0.99      0.99      0.99       214
#  Command and control       0.99      0.99      0.99       514
#           Collection       0.99      1.00      0.99       620
#               Impact       0.99      0.99      0.99       154
#
#            micro avg       0.99      0.99      0.99      3680
#            macro avg       0.99      0.99      0.99      3680
#         weighted avg       0.99      0.99      0.99      3680
#          samples avg       0.99      0.99      0.99      3680
#
# Multilabel Confusion Matrix:
# [[[564   2]
#   [  1 133]]
#
#  [[ 89   3]
#   [  7 601]]
#
#  [[110   8]
#   [  2 580]]
#
#  [[277   1]
#   [  2 420]]
#
#  [[659   2]
#   [  0  39]]
#
#  [[438   5]
#   [  2 255]]
#
#  [[564   0]
#   [  2 134]]
#
#  [[484   2]
#   [  3 211]]
#
#  [[180   6]
#   [  3 511]]
#
#  [[ 74   6]
#   [  1 619]]
#
#  [[544   2]
#   [  2 152]]]
#
#
#
#
# ********** Random Seed: 354 **********
#
#
# Evaluating Label Powerset
# Accuracy: 0.97
# Macro F1 Score: 0.9828789691722477
# Weighted F1 score: 0.988169960276152
# Micro F1 score: 0.9881616546468908
# Macro Precision: 0.9820003417795021
# Weighted Precision: 0.9851875285458049
# Micro Precision: 0.9850786760716224
# Macro Recall: 0.9840606400438947
# Weighted Recall: 0.9912639912639912
# Micro Recall: 0.9912639912639912
# Hamming Loss: 0.0112987012987013
# Zero One Loss: 0.030000000000000027
# Jaccard Similarity: 0.9791054421768708
# Classification Report:
#                       precision    recall  f1-score   support
#
#    Credential Access       0.98      0.99      0.98       163
#      Defence Evasion       0.99      1.00      0.99       607
#            Discovery       0.99      1.00      0.99       569
#            Execution       0.98      0.99      0.99       402
#       Initial Access       0.97      0.92      0.95        38
#          Persistance       1.00      1.00      1.00       240
#         Exfiltration       0.94      0.99      0.97       145
# Privilage Escalation       0.99      0.99      0.99       195
#  Command and control       0.99      0.99      0.99       520
#           Collection       0.99      0.99      0.99       614
#               Impact       0.99      0.97      0.98       170
#
#            micro avg       0.99      0.99      0.99      3663
#            macro avg       0.98      0.98      0.98      3663
#         weighted avg       0.99      0.99      0.99      3663
#          samples avg       0.98      0.99      0.98      3663
#
# Multilabel Confusion Matrix:
# [[[533   4]
#   [  2 161]]
#
#  [[ 85   8]
#   [  3 604]]
#
#  [[124   7]
#   [  2 567]]
#
#  [[289   9]
#   [  3 399]]
#
#  [[661   1]
#   [  3  35]]
#
#  [[459   1]
#   [  1 239]]
#
#  [[546   9]
#   [  1 144]]
#
#  [[504   1]
#   [  2 193]]
#
#  [[174   6]
#   [  4 516]]
#
#  [[ 78   8]
#   [  6 608]]
#
#  [[529   1]
#   [  5 165]]]
#
#
#
#
# ********** Random Seed: 560 **********
#
#
# Evaluating Label Powerset
# Accuracy: 0.9614285714285714
# Macro F1 Score: 0.9773589483946733
# Weighted F1 score: 0.9866419161297869
# Micro F1 score: 0.9866702937976061
# Macro Precision: 0.9774677831163081
# Weighted Precision: 0.9845176329391362
# Micro Precision: 0.9845276872964169
# Macro Recall: 0.9773688079011041
# Weighted Recall: 0.9888222464558343
# Micro Recall: 0.9888222464558343
# Hamming Loss: 0.012727272727272728
# Zero One Loss: 0.03857142857142859
# Jaccard Similarity: 0.9759784580498867
# Classification Report:
#                       precision    recall  f1-score   support
#
#    Credential Access       0.97      0.97      0.97       157
#      Defence Evasion       0.99      0.99      0.99       608
#            Discovery       0.99      0.99      0.99       567
#            Execution       0.98      1.00      0.99       408
#       Initial Access       0.93      0.90      0.92        30
#          Persistance       0.99      0.99      0.99       245
#         Exfiltration       0.97      0.99      0.98       129
# Privilage Escalation       0.99      0.98      0.98       209
#  Command and control       0.98      0.99      0.99       532
#           Collection       0.99      1.00      1.00       614
#               Impact       0.97      0.95      0.96       169
#
#            micro avg       0.98      0.99      0.99      3668
#            macro avg       0.98      0.98      0.98      3668
#         weighted avg       0.98      0.99      0.99      3668
#          samples avg       0.98      0.99      0.98      3668
#
# Multilabel Confusion Matrix:
# [[[539   4]
#   [  4 153]]
#
#  [[ 83   9]
#   [  4 604]]
#
#  [[127   6]
#   [  5 562]]
#
#  [[283   9]
#   [  2 406]]
#
#  [[668   2]
#   [  3  27]]
#
#  [[453   2]
#   [  3 242]]
#
#  [[567   4]
#   [  1 128]]
#
#  [[488   3]
#   [  4 205]]
#
#  [[159   9]
#   [  4 528]]
#
#  [[ 82   4]
#   [  2 612]]
#
#  [[526   5]
#   [  9 160]]]
#
#
#
#
# ********** Random Seed: 1600 **********
#
#
# Evaluating Label Powerset
# Accuracy: 0.9742857142857143
# Macro F1 Score: 0.9897172025081282
# Weighted F1 score: 0.9916083051740945
# Micro F1 score: 0.9916234543278819
# Macro Precision: 0.9888834323022068
# Weighted Precision: 0.9904348427117833
# Micro Precision: 0.9904382470119522
# Macro Recall: 0.9905987164024311
# Weighted Recall: 0.9928115015974441
# Micro Recall: 0.9928115015974441
# Hamming Loss: 0.008181818181818182
# Zero One Loss: 0.02571428571428569
# Jaccard Similarity: 0.9849812925170067
# Classification Report:
#                       precision    recall  f1-score   support
#
#    Credential Access       0.98      0.96      0.97       141
#      Defence Evasion       0.99      1.00      1.00       607
#            Discovery       0.99      1.00      0.99       597
#            Execution       0.99      1.00      0.99       424
#       Initial Access       1.00      1.00      1.00        43
#          Persistance       0.99      1.00      0.99       271
#         Exfiltration       0.98      1.00      0.99       140
# Privilage Escalation       0.99      1.00      0.99       225
#  Command and control       0.99      0.98      0.99       523
#           Collection       0.99      1.00      0.99       627
#               Impact       0.98      0.97      0.97       158
#
#            micro avg       0.99      0.99      0.99      3756
#            macro avg       0.99      0.99      0.99      3756
#         weighted avg       0.99      0.99      0.99      3756
#          samples avg       0.99      0.99      0.99      3756
#
# Multilabel Confusion Matrix:
# [[[556   3]
#   [  5 136]]
#
#  [[ 89   4]
#   [  2 605]]
#
#  [[ 98   5]
#   [  1 596]]
#
#  [[272   4]
#   [  2 422]]
#
#  [[657   0]
#   [  0  43]]
#
#  [[427   2]
#   [  1 270]]
#
#  [[557   3]
#   [  0 140]]
#
#  [[472   3]
#   [  1 224]]
#
#  [[173   4]
#   [  8 515]]
#
#  [[ 68   5]
#   [  2 625]]
#
#  [[539   3]
#   [  5 153]]]
#
#
# Number of samples to generate for 50% of max count: 1232
# 1340
#
#
# ********** Random Seed: 42 **********
#
#
# Evaluating Label Powerset
# Accuracy: 0.9708383961117861
# Macro F1 Score: 0.9883752367459003
# Weighted F1 score: 0.9908006333522666
# Micro F1 score: 0.9907979033197437
# Macro Precision: 0.9864667008994619
# Weighted Precision: 0.9897816883369897
# Micro Precision: 0.9897602978822434
# Macro Recall: 0.9903150397264265
# Weighted Recall: 0.9918376865671642
# Micro Recall: 0.9918376865671642
# Hamming Loss: 0.008726389042306418
# Zero One Loss: 0.02916160388821387
# Jaccard Similarity: 0.9822590599625838
# Classification Report:
#                       precision    recall  f1-score   support
#
#    Credential Access       0.98      0.98      0.98       182
#      Defence Evasion       1.00      0.99      0.99       694
#            Discovery       0.99      0.99      0.99       690
#            Execution       0.99      1.00      0.99       474
#       Initial Access       0.99      1.00      0.99        69
#          Persistance       0.98      1.00      0.99       253
#         Exfiltration       1.00      0.99      0.99       214
# Privilage Escalation       0.98      0.98      0.98       207
#  Command and control       0.99      0.98      0.99       594
#           Collection       0.99      1.00      0.99       722
#               Impact       0.97      0.98      0.97       189
#
#            micro avg       0.99      0.99      0.99      4288
#            macro avg       0.99      0.99      0.99      4288
#         weighted avg       0.99      0.99      0.99      4288
#          samples avg       0.99      0.99      0.99      4288
#
# Multilabel Confusion Matrix:
# [[[637   4]
#   [  3 179]]
#
#  [[126   3]
#   [  4 690]]
#
#  [[129   4]
#   [  4 686]]
#
#  [[345   4]
#   [  1 473]]
#
#  [[753   1]
#   [  0  69]]
#
#  [[566   4]
#   [  1 252]]
#
#  [[608   1]
#   [  3 211]]
#
#  [[611   5]
#   [  4 203]]
#
#  [[223   6]
#   [  9 585]]
#
#  [[ 95   6]
#   [  2 720]]
#
#  [[628   6]
#   [  4 185]]]
#
#
#
#
# ********** Random Seed: 1433 **********
#
#
# Evaluating Label Powerset
# Accuracy: 0.9744835965978129
# Macro F1 Score: 0.9877108381093384
# Weighted F1 score: 0.9905243150347138
# Micro F1 score: 0.9905268022181146
# Macro Precision: 0.9850767134055317
# Weighted Precision: 0.9871396354758903
# Micro Precision: 0.9871056873129174
# Macro Recall: 0.9904329443394069
# Weighted Recall: 0.9939717134245305
# Micro Recall: 0.9939717134245305
# Hamming Loss: 0.009057770904672484
# Zero One Loss: 0.025516403402187082
# Jaccard Similarity: 0.9834548400162009
# Classification Report:
#                       precision    recall  f1-score   support
#
#    Credential Access       0.96      0.99      0.97       213
#      Defence Evasion       0.99      1.00      0.99       709
#            Discovery       0.99      1.00      0.99       699
#            Execution       0.98      1.00      0.99       431
#       Initial Access       0.98      0.98      0.98        64
#          Persistance       0.99      0.99      0.99       250
#         Exfiltration       0.99      1.00      0.99       252
# Privilage Escalation       0.98      0.98      0.98       187
#  Command and control       0.99      0.99      0.99       583
#           Collection       0.99      1.00      0.99       728
#               Impact       0.99      0.96      0.98       197
#
#            micro avg       0.99      0.99      0.99      4313
#            macro avg       0.99      0.99      0.99      4313
#         weighted avg       0.99      0.99      0.99      4313
#          samples avg       0.99      0.99      0.99      4313
#
# Multilabel Confusion Matrix:
# [[[601   9]
#   [  3 210]]
#
#  [[108   6]
#   [  2 707]]
#
#  [[116   8]
#   [  3 696]]
#
#  [[385   7]
#   [  1 430]]
#
#  [[758   1]
#   [  1  63]]
#
#  [[570   3]
#   [  2 248]]
#
#  [[568   3]
#   [  0 252]]
#
#  [[633   3]
#   [  3 184]]
#
#  [[233   7]
#   [  3 580]]
#
#  [[ 88   7]
#   [  1 727]]
#
#  [[624   2]
#   [  7 190]]]
#
#
#
#
# ********** Random Seed: 2396 **********
#
#
# Evaluating Label Powerset
# Accuracy: 0.9708383961117861
# Macro F1 Score: 0.9865776614291805
# Weighted F1 score: 0.9902320030218921
# Micro F1 score: 0.9902467010900746
# Macro Precision: 0.9870761866071408
# Weighted Precision: 0.9892257582514996
# Micro Precision: 0.98922512608895
# Macro Recall: 0.9861543750798222
# Weighted Recall: 0.9912703882379967
# Micro Recall: 0.9912703882379967
# Hamming Loss: 0.00938915276703855
# Zero One Loss: 0.02916160388821387
# Jaccard Similarity: 0.9811635711392697
# Classification Report:
#                       precision    recall  f1-score   support
#
#    Credential Access       0.97      0.96      0.97       217
#      Defence Evasion       0.99      0.99      0.99       715
#            Discovery       0.99      1.00      0.99       694
#            Execution       0.99      1.00      0.99       450
#       Initial Access       1.00      0.97      0.99        68
#          Persistance       0.98      0.99      0.99       246
#         Exfiltration       0.98      1.00      0.99       233
# Privilage Escalation       0.98      0.98      0.98       189
#  Command and control       0.99      0.99      0.99       592
#           Collection       1.00      0.99      1.00       744
#               Impact       0.98      0.97      0.97       205
#
#            micro avg       0.99      0.99      0.99      4353
#            macro avg       0.99      0.99      0.99      4353
#         weighted avg       0.99      0.99      0.99      4353
#          samples avg       0.99      0.99      0.98      4353
#
# Multilabel Confusion Matrix:
# [[[600   6]
#   [  8 209]]
#
#  [[103   5]
#   [  4 711]]
#
#  [[122   7]
#   [  3 691]]
#
#  [[369   4]
#   [  1 449]]
#
#  [[755   0]
#   [  2  66]]
#
#  [[573   4]
#   [  2 244]]
#
#  [[586   4]
#   [  0 233]]
#
#  [[630   4]
#   [  4 185]]
#
#  [[224   7]
#   [  3 589]]
#
#  [[ 77   2]
#   [  4 740]]
#
#  [[614   4]
#   [  7 198]]]
#
#
#
#
# ********** Random Seed: 451 **********
#
#
# Evaluating Label Powerset
# Accuracy: 0.9696233292831106
# Macro F1 Score: 0.9859643524631874
# Weighted F1 score: 0.9895041871218005
# Micro F1 score: 0.9895282062830763
# Macro Precision: 0.9857263091049119
# Weighted Precision: 0.9892383950609711
# Micro Precision: 0.9891940567312022
# Macro Recall: 0.9863742320440122
# Weighted Recall: 0.9898625816625366
# Micro Recall: 0.9898625816625366
# Hamming Loss: 0.010272837733348061
# Zero One Loss: 0.03037667071688943
# Jaccard Similarity: 0.9830628363131401
# Classification Report:
#                       precision    recall  f1-score   support
#
#    Credential Access       0.96      0.97      0.97       189
#      Defence Evasion       0.99      1.00      0.99       718
#            Discovery       0.99      1.00      0.99       716
#            Execution       0.99      0.99      0.99       491
#       Initial Access       0.97      1.00      0.98        64
#          Persistance       1.00      0.95      0.97       284
#         Exfiltration       0.99      1.00      0.99       213
# Privilage Escalation       1.00      0.99      0.99       215
#  Command and control       0.99      0.99      0.99       612
#           Collection       0.99      1.00      1.00       743
#               Impact       0.98      0.96      0.97       194
#
#            micro avg       0.99      0.99      0.99      4439
#            macro avg       0.99      0.99      0.99      4439
#         weighted avg       0.99      0.99      0.99      4439
#          samples avg       0.99      0.99      0.99      4439
#
# Multilabel Confusion Matrix:
# [[[626   8]
#   [  5 184]]
#
#  [[ 99   6]
#   [  2 716]]
#
#  [[100   7]
#   [  3 713]]
#
#  [[326   6]
#   [  4 487]]
#
#  [[757   2]
#   [  0  64]]
#
#  [[538   1]
#   [ 13 271]]
#
#  [[607   3]
#   [  0 213]]
#
#  [[607   1]
#   [  3 212]]
#
#  [[204   7]
#   [  6 606]]
#
#  [[ 76   4]
#   [  2 741]]
#
#  [[626   3]
#   [  7 187]]]
#
#
#
#
# ********** Random Seed: 995 **********
#
#
# Evaluating Label Powerset
# Accuracy: 0.9756986634264885
# Macro F1 Score: 0.9886831230491424
# Weighted F1 score: 0.9913948731120765
# Micro F1 score: 0.9913988229968311
# Macro Precision: 0.9888154063716783
# Weighted Precision: 0.9902864192326982
# Micro Precision: 0.9902780917929007
# Macro Recall: 0.9886103126359814
# Weighted Recall: 0.9925220938137321
# Micro Recall: 0.9925220938137321
# Hamming Loss: 0.008395007179940352
# Zero One Loss: 0.024301336573511523
# Jaccard Similarity: 0.9839813689752935
# Classification Report:
#                       precision    recall  f1-score   support
#
#    Credential Access       0.98      0.98      0.98       187
#      Defence Evasion       0.99      0.99      0.99       712
#            Discovery       0.99      1.00      0.99       721
#            Execution       0.99      0.99      0.99       472
#       Initial Access       1.00      0.97      0.98        65
#          Persistance       0.98      0.99      0.99       292
#         Exfiltration       0.99      1.00      0.99       233
# Privilage Escalation       0.99      0.99      0.99       228
#  Command and control       0.99      0.99      0.99       600
#           Collection       1.00      0.99      1.00       732
#               Impact       0.98      0.97      0.97       171
#
#            micro avg       0.99      0.99      0.99      4413
#            macro avg       0.99      0.99      0.99      4413
#         weighted avg       0.99      0.99      0.99      4413
#          samples avg       0.99      0.99      0.99      4413
#
# Multilabel Confusion Matrix:
# [[[632   4]
#   [  4 183]]
#
#  [[104   7]
#   [  4 708]]
#
#  [[ 97   5]
#   [  3 718]]
#
#  [[346   5]
#   [  3 469]]
#
#  [[758   0]
#   [  2  63]]
#
#  [[526   5]
#   [  2 290]]
#
#  [[587   3]
#   [  0 233]]
#
#  [[593   2]
#   [  2 226]]
#
#  [[218   5]
#   [  4 596]]
#
#  [[ 88   3]
#   [  4 728]]
#
#  [[648   4]
#   [  5 166]]]
#
#
#
#
# ********** Random Seed: 98 **********
#
#
# Evaluating Label Powerset
# Accuracy: 0.9805589307411907
# Macro F1 Score: 0.9896301844847698
# Weighted F1 score: 0.9933449292844695
# Micro F1 score: 0.9933516735442458
# Macro Precision: 0.9897005049778875
# Weighted Precision: 0.9911464853276458
# Micro Precision: 0.9910795974382434
# Macro Recall: 0.9898729942897421
# Weighted Recall: 0.9956341911764706
# Micro Recall: 0.9956341911764706
# Hamming Loss: 0.006406716005743952
# Zero One Loss: 0.019441069258809285
# Jaccard Similarity: 0.9886738413469882
# Classification Report:
#                       precision    recall  f1-score   support
#
#    Credential Access       0.98      0.99      0.99       194
#      Defence Evasion       0.99      1.00      0.99       705
#            Discovery       1.00      1.00      1.00       707
#            Execution       0.99      1.00      0.99       460
#       Initial Access       1.00      0.93      0.96        69
#          Persistance       1.00      1.00      1.00       260
#         Exfiltration       0.97      1.00      0.99       236
# Privilage Escalation       0.98      0.99      0.99       197
#  Command and control       0.99      1.00      0.99       593
#           Collection       1.00      1.00      1.00       741
#               Impact       0.99      0.99      0.99       190
#
#            micro avg       0.99      1.00      0.99      4352
#            macro avg       0.99      0.99      0.99      4352
#         weighted avg       0.99      1.00      0.99      4352
#          samples avg       0.99      0.99      0.99      4352
#
# Multilabel Confusion Matrix:
# [[[625   4]
#   [  1 193]]
#
#  [[111   7]
#   [  1 704]]
#
#  [[115   1]
#   [  2 705]]
#
#  [[357   6]
#   [  2 458]]
#
#  [[754   0]
#   [  5  64]]
#
#  [[563   0]
#   [  1 259]]
#
#  [[580   7]
#   [  0 236]]
#
#  [[623   3]
#   [  1 196]]
#
#  [[223   7]
#   [  1 592]]
#
#  [[ 80   2]
#   [  3 738]]
#
#  [[631   2]
#   [  2 188]]]
#
#
#
#
# ********** Random Seed: 262 **********
#
#
# Evaluating Label Powerset
# Accuracy: 0.976913730255164
# Macro F1 Score: 0.9888685745886355
# Weighted F1 score: 0.9928544888587326
# Micro F1 score: 0.992849846782431
# Macro Precision: 0.987202628044355
# Weighted Precision: 0.9914119865650114
# Micro Precision: 0.9913871260199456
# Macro Recall: 0.9905639429043247
# Weighted Recall: 0.9943168902023187
# Micro Recall: 0.9943168902023187
# Hamming Loss: 0.006959019109687397
# Zero One Loss: 0.023086269744835963
# Jaccard Similarity: 0.9876222299369323
# Classification Report:
#                       precision    recall  f1-score   support
#
#    Credential Access       0.97      0.98      0.98       187
#      Defence Evasion       0.99      1.00      1.00       718
#            Discovery       1.00      1.00      1.00       713
#            Execution       0.99      0.99      0.99       472
#       Initial Access       0.97      0.97      0.97        65
#          Persistance       0.98      1.00      0.99       289
#         Exfiltration       1.00      0.98      0.99       226
# Privilage Escalation       0.99      1.00      0.99       224
#  Command and control       0.99      0.99      0.99       588
#           Collection       1.00      1.00      1.00       745
#               Impact       0.98      0.99      0.99       172
#
#            micro avg       0.99      0.99      0.99      4399
#            macro avg       0.99      0.99      0.99      4399
#         weighted avg       0.99      0.99      0.99      4399
#          samples avg       0.99      0.99      0.99      4399
#
# Multilabel Confusion Matrix:
# [[[631   5]
#   [  3 184]]
#
#  [[101   4]
#   [  2 716]]
#
#  [[107   3]
#   [  2 711]]
#
#  [[347   4]
#   [  3 469]]
#
#  [[756   2]
#   [  2  63]]
#
#  [[529   5]
#   [  1 288]]
#
#  [[596   1]
#   [  4 222]]
#
#  [[596   3]
#   [  1 223]]
#
#  [[228   7]
#   [  3 585]]
#
#  [[ 77   1]
#   [  2 743]]
#
#  [[648   3]
#   [  2 170]]]
#
#
#
#
# ********** Random Seed: 354 **********
#
#
# Evaluating Label Powerset
# Accuracy: 0.9720534629404617
# Macro F1 Score: 0.9868581663819209
# Weighted F1 score: 0.9901075462484158
# Micro F1 score: 0.9901240238860818
# Macro Precision: 0.9868878470129375
# Weighted Precision: 0.9876790641346822
# Micro Precision: 0.9876288659793815
# Macro Recall: 0.9870594463669687
# Weighted Recall: 0.992631821321667
# Micro Recall: 0.992631821321667
# Hamming Loss: 0.00949961338782724
# Zero One Loss: 0.027946537059538312
# Jaccard Similarity: 0.9810189203263322
# Classification Report:
#                       precision    recall  f1-score   support
#
#    Credential Access       0.97      1.00      0.98       203
#      Defence Evasion       0.99      1.00      0.99       703
#            Discovery       0.99      1.00      0.99       703
#            Execution       0.98      1.00      0.99       458
#       Initial Access       1.00      0.95      0.98        63
#          Persistance       1.00      0.99      0.99       265
#         Exfiltration       0.97      1.00      0.99       240
# Privilage Escalation       0.99      0.99      0.99       194
#  Command and control       0.99      0.99      0.99       593
#           Collection       0.99      1.00      1.00       735
#               Impact       0.98      0.95      0.97       186
#
#            micro avg       0.99      0.99      0.99      4343
#            macro avg       0.99      0.99      0.99      4343
#         weighted avg       0.99      0.99      0.99      4343
#          samples avg       0.99      0.99      0.98      4343
#
# Multilabel Confusion Matrix:
# [[[614   6]
#   [  1 202]]
#
#  [[110  10]
#   [  3 700]]
#
#  [[113   7]
#   [  3 700]]
#
#  [[358   7]
#   [  1 457]]
#
#  [[760   0]
#   [  3  60]]
#
#  [[557   1]
#   [  2 263]]
#
#  [[576   7]
#   [  0 240]]
#
#  [[627   2]
#   [  2 192]]
#
#  [[223   7]
#   [  6 587]]
#
#  [[ 84   4]
#   [  2 733]]
#
#  [[634   3]
#   [  9 177]]]
#
#
#
#
# ********** Random Seed: 560 **********
#
#
# Evaluating Label Powerset
# Accuracy: 0.9659781287970839
# Macro F1 Score: 0.9858487463497831
# Weighted F1 score: 0.9882438926284185
# Micro F1 score: 0.9882515549412578
# Macro Precision: 0.9810180891011917
# Weighted Precision: 0.9834924423772904
# Micro Precision: 0.9834938101788171
# Macro Recall: 0.990762426072721
# Weighted Recall: 0.9930555555555556
# Micro Recall: 0.9930555555555556
# Hamming Loss: 0.011266983320446261
# Zero One Loss: 0.03402187120291611
# Jaccard Similarity: 0.9763568246253544
# Classification Report:
#                       precision    recall  f1-score   support
#
#    Credential Access       0.98      0.97      0.98       198
#      Defence Evasion       0.99      1.00      0.99       704
#            Discovery       0.98      0.99      0.99       701
#            Execution       0.98      1.00      0.99       441
#       Initial Access       0.97      1.00      0.99        67
#          Persistance       0.98      0.99      0.99       265
#         Exfiltration       0.99      1.00      0.99       243
# Privilage Escalation       0.98      0.98      0.98       196
#  Command and control       0.98      1.00      0.99       587
#           Collection       0.99      1.00      0.99       728
#               Impact       0.97      0.97      0.97       190
#
#            micro avg       0.98      0.99      0.99      4320
#            macro avg       0.98      0.99      0.99      4320
#         weighted avg       0.98      0.99      0.99      4320
#          samples avg       0.98      0.99      0.98      4320
#
# Multilabel Confusion Matrix:
# [[[621   4]
#   [  5 193]]
#
#  [[110   9]
#   [  2 702]]
#
#  [[111  11]
#   [  6 695]]
#
#  [[374   8]
#   [  2 439]]
#
#  [[754   2]
#   [  0  67]]
#
#  [[553   5]
#   [  2 263]]
#
#  [[577   3]
#   [  0 243]]
#
#  [[623   4]
#   [  4 192]]
#
#  [[225  11]
#   [  2 585]]
#
#  [[ 86   9]
#   [  2 726]]
#
#  [[627   6]
#   [  5 185]]]
#
#
#
#
# ********** Random Seed: 1600 **********
#
#
# Evaluating Label Powerset
# Accuracy: 0.9817739975698664
# Macro F1 Score: 0.9917775023120776
# Weighted F1 score: 0.9940184632724244
# Micro F1 score: 0.9940202391904324
# Macro Precision: 0.9916640433011691
# Weighted Precision: 0.9940362672548176
# Micro Precision: 0.9940202391904324
# Macro Recall: 0.9919310915627935
# Weighted Recall: 0.9940202391904324
# Micro Recall: 0.9940202391904324
# Hamming Loss: 0.005743952281011819
# Zero One Loss: 0.018226002430133614
# Jaccard Similarity: 0.9893797373141237
# Classification Report:
#                       precision    recall  f1-score   support
#
#    Credential Access       0.98      0.99      0.98       175
#      Defence Evasion       1.00      1.00      1.00       702
#            Discovery       0.99      1.00      1.00       711
#            Execution       0.99      0.99      0.99       478
#       Initial Access       0.98      1.00      0.99        59
#          Persistance       1.00      0.99      0.99       279
#         Exfiltration       0.99      1.00      0.99       235
# Privilage Escalation       1.00      0.99      0.99       225
#  Command and control       0.99      0.99      0.99       596
#           Collection       1.00      1.00      1.00       726
#               Impact       0.98      0.98      0.98       162
#
#            micro avg       0.99      0.99      0.99      4348
#            macro avg       0.99      0.99      0.99      4348
#         weighted avg       0.99      0.99      0.99      4348
#          samples avg       0.99      0.99      0.99      4348
#
# Multilabel Confusion Matrix:
# [[[644   4]
#   [  2 173]]
#
#  [[118   3]
#   [  2 700]]
#
#  [[108   4]
#   [  1 710]]
#
#  [[342   3]
#   [  4 474]]
#
#  [[763   1]
#   [  0  59]]
#
#  [[544   0]
#   [  4 275]]
#
#  [[586   2]
#   [  1 234]]
#
#  [[598   0]
#   [  3 222]]
#
#  [[224   3]
#   [  4 592]]
#
#  [[ 94   3]
#   [  1 725]]
#
#  [[658   3]
#   [  4 158]]]
#
#
# Number of samples to generate for 75% of max count: 1848
# 1956
#
#
# ********** Random Seed: 42 **********
#
#
# Evaluating Label Powerset
# Accuracy: 0.9830866807610994
# Macro F1 Score: 0.9954189115689327
# Weighted F1 score: 0.9963558065761013
# Micro F1 score: 0.996356474643033
# Macro Precision: 0.995694386711202
# Weighted Precision: 0.9962667977631536
# Micro Precision: 0.9962583694367861
# Macro Recall: 0.995155144397388
# Weighted Recall: 0.9964545991727398
# Micro Recall: 0.9964545991727398
# Hamming Loss: 0.0035556409763597926
# Zero One Loss: 0.016913319238900604
# Jaccard Similarity: 0.9916993858854323
# Classification Report:
#                       precision    recall  f1-score   support
#
#    Credential Access       1.00      0.99      0.99       263
#      Defence Evasion       1.00      1.00      1.00       822
#            Discovery       1.00      1.00      1.00       820
#            Execution       0.99      1.00      1.00       521
#       Initial Access       1.00      1.00      1.00        93
#          Persistance       0.99      0.99      0.99       286
#         Exfiltration       1.00      1.00      1.00       341
# Privilage Escalation       0.99      0.99      0.99       200
#  Command and control       0.99      1.00      0.99       677
#           Collection       1.00      1.00      1.00       849
#               Impact       1.00      0.99      0.99       205
#
#            micro avg       1.00      1.00      1.00      5077
#            macro avg       1.00      1.00      1.00      5077
#         weighted avg       1.00      1.00      1.00      5077
#          samples avg       0.99      0.99      0.99      5077
#
# Multilabel Confusion Matrix:
# [[[682   1]
#   [  3 260]]
#
#  [[124   0]
#   [  4 818]]
#
#  [[124   2]
#   [  2 818]]
#
#  [[422   3]
#   [  0 521]]
#
#  [[853   0]
#   [  0  93]]
#
#  [[657   3]
#   [  2 284]]
#
#  [[605   0]
#   [  0 341]]
#
#  [[744   2]
#   [  2 198]]
#
#  [[263   6]
#   [  2 675]]
#
#  [[ 96   1]
#   [  0 849]]
#
#  [[740   1]
#   [  3 202]]]
#
#
#
#
# ********** Random Seed: 1433 **********
#
#
# Evaluating Label Powerset
# Accuracy: 0.9767441860465116
# Macro F1 Score: 0.9919655609149696
# Weighted F1 score: 0.9932497383945792
# Micro F1 score: 0.9932432432432432
# Macro Precision: 0.9903364396322822
# Weighted Precision: 0.9930709142228128
# Micro Precision: 0.9930458970792768
# Macro Recall: 0.9936194539723715
# Weighted Recall: 0.9934406678592725
# Micro Recall: 0.9934406678592725
# Hamming Loss: 0.0065346915241206996
# Zero One Loss: 0.023255813953488413
# Jaccard Similarity: 0.9854827343199436
# Classification Report:
#                       precision    recall  f1-score   support
#
#    Credential Access       0.98      0.98      0.98       253
#      Defence Evasion       1.00      0.99      0.99       826
#            Discovery       0.99      1.00      0.99       817
#            Execution       1.00      0.99      1.00       501
#       Initial Access       0.99      1.00      0.99        89
#          Persistance       0.99      0.99      0.99       286
#         Exfiltration       1.00      1.00      1.00       343
# Privilage Escalation       0.97      0.99      0.98       196
#  Command and control       1.00      0.99      1.00       670
#           Collection       0.99      0.99      0.99       836
#               Impact       0.99      1.00      0.99       214
#
#            micro avg       0.99      0.99      0.99      5031
#            macro avg       0.99      0.99      0.99      5031
#         weighted avg       0.99      0.99      0.99      5031
#          samples avg       0.99      0.99      0.99      5031
#
# Multilabel Confusion Matrix:
# [[[687   6]
#   [  4 249]]
#
#  [[117   3]
#   [  7 819]]
#
#  [[124   5]
#   [  4 813]]
#
#  [[443   2]
#   [  3 498]]
#
#  [[856   1]
#   [  0  89]]
#
#  [[658   2]
#   [  2 284]]
#
#  [[602   1]
#   [  0 343]]
#
#  [[745   5]
#   [  2 194]]
#
#  [[274   2]
#   [  4 666]]
#
#  [[105   5]
#   [  6 830]]
#
#  [[729   3]
#   [  1 213]]]
#
#
#
#
# ********** Random Seed: 2396 **********
#
#
# Evaluating Label Powerset
# Accuracy: 0.9778012684989429
# Macro F1 Score: 0.9888033121783139
# Weighted F1 score: 0.9918828237970497
# Micro F1 score: 0.9918731814989465
# Macro Precision: 0.9846423113918165
# Weighted Precision: 0.9890365837108633
# Micro Precision: 0.9889955982392957
# Macro Recall: 0.9930355282951246
# Weighted Recall: 0.9947675588649628
# Micro Recall: 0.9947675588649628
# Hamming Loss: 0.007783970786084951
# Zero One Loss: 0.022198731501057112
# Jaccard Similarity: 0.9864508876136783
# Classification Report:
#                       precision    recall  f1-score   support
#
#    Credential Access       0.97      0.98      0.97       245
#      Defence Evasion       1.00      1.00      1.00       807
#            Discovery       0.99      1.00      0.99       819
#            Execution       0.99      1.00      0.99       493
#       Initial Access       0.97      0.99      0.98       104
#          Persistance       0.98      1.00      0.99       278
#         Exfiltration       0.99      1.00      1.00       336
# Privilage Escalation       0.97      0.99      0.98       191
#  Command and control       0.99      1.00      0.99       645
#           Collection       0.99      1.00      1.00       841
#               Impact       0.99      0.98      0.98       210
#
#            micro avg       0.99      0.99      0.99      4969
#            macro avg       0.98      0.99      0.99      4969
#         weighted avg       0.99      0.99      0.99      4969
#          samples avg       0.99      0.99      0.99      4969
#
# Multilabel Confusion Matrix:
# [[[693   8]
#   [  5 240]]
#
#  [[136   3]
#   [  3 804]]
#
#  [[121   6]
#   [  4 815]]
#
#  [[447   6]
#   [  2 491]]
#
#  [[839   3]
#   [  1 103]]
#
#  [[662   6]
#   [  0 278]]
#
#  [[608   2]
#   [  1 335]]
#
#  [[750   5]
#   [  1 190]]
#
#  [[293   8]
#   [  2 643]]
#
#  [[100   5]
#   [  3 838]]
#
#  [[733   3]
#   [  4 206]]]
#
#
#
#
# ********** Random Seed: 451 **********
#
#
# Evaluating Label Powerset
# Accuracy: 0.9820295983086681
# Macro F1 Score: 0.9933115542874886
# Weighted F1 score: 0.9945241213583036
# Micro F1 score: 0.9945235487404163
# Macro Precision: 0.9915124906553305
# Weighted Precision: 0.9930485039083528
# Micro Precision: 0.9930403658779081
# Macro Recall: 0.9951278290608996
# Weighted Recall: 0.9960111687275628
# Micro Recall: 0.9960111687275628
# Hamming Loss: 0.005285412262156448
# Zero One Loss: 0.017970401691331905
# Jaccard Similarity: 0.9874257525420317
# Classification Report:
#                       precision    recall  f1-score   support
#
#    Credential Access       0.98      0.99      0.99       245
#      Defence Evasion       1.00      1.00      1.00       803
#            Discovery       0.99      1.00      0.99       807
#            Execution       0.99      1.00      0.99       513
#       Initial Access       0.99      1.00      0.99        91
#          Persistance       0.99      1.00      1.00       307
#         Exfiltration       0.99      1.00      1.00       293
# Privilage Escalation       1.00      0.99      0.99       216
#  Command and control       1.00      0.99      0.99       673
#           Collection       1.00      1.00      1.00       839
#               Impact       0.98      0.98      0.98       227
#
#            micro avg       0.99      1.00      0.99      5014
#            macro avg       0.99      1.00      0.99      5014
#         weighted avg       0.99      1.00      0.99      5014
#          samples avg       0.99      0.99      0.99      5014
#
# Multilabel Confusion Matrix:
# [[[697   4]
#   [  2 243]]
#
#  [[140   3]
#   [  2 801]]
#
#  [[133   6]
#   [  3 804]]
#
#  [[427   6]
#   [  1 512]]
#
#  [[854   1]
#   [  0  91]]
#
#  [[637   2]
#   [  1 306]]
#
#  [[651   2]
#   [  0 293]]
#
#  [[729   1]
#   [  2 214]]
#
#  [[270   3]
#   [  4 669]]
#
#  [[104   3]
#   [  1 838]]
#
#  [[715   4]
#   [  4 223]]]
#
#
#
#
# ********** Random Seed: 995 **********
#
#
# Evaluating Label Powerset
# Accuracy: 0.9788583509513742
# Macro F1 Score: 0.9923714391394882
# Weighted F1 score: 0.9937070310243558
# Micro F1 score: 0.9937106918238994
# Macro Precision: 0.9956249574490258
# Weighted Precision: 0.9963255618520904
# Micro Precision: 0.9963135428793171
# Macro Recall: 0.989174988052202
# Weighted Recall: 0.991121405134144
# Micro Recall: 0.991121405134144
# Hamming Loss: 0.006246396309821257
# Zero One Loss: 0.02114164904862581
# Jaccard Similarity: 0.9879089902345717
# Classification Report:
#                       precision    recall  f1-score   support
#
#    Credential Access       0.99      0.99      0.99       248
#      Defence Evasion       1.00      1.00      1.00       831
#            Discovery       1.00      0.99      0.99       837
#            Execution       1.00      0.99      1.00       519
#       Initial Access       1.00      0.98      0.99        90
#          Persistance       0.99      0.99      0.99       324
#         Exfiltration       0.99      0.99      0.99       334
# Privilage Escalation       1.00      0.99      1.00       228
#  Command and control       1.00      0.98      0.99       697
#           Collection       1.00      0.99      1.00       867
#               Impact       1.00      0.98      0.99       206
#
#            micro avg       1.00      0.99      0.99      5181
#            macro avg       1.00      0.99      0.99      5181
#         weighted avg       1.00      0.99      0.99      5181
#          samples avg       0.99      0.99      0.99      5181
#
# Multilabel Confusion Matrix:
# [[[695   3]
#   [  2 246]]
#
#  [[112   3]
#   [  3 828]]
#
#  [[108   1]
#   [  8 829]]
#
#  [[425   2]
#   [  3 516]]
#
#  [[856   0]
#   [  2  88]]
#
#  [[620   2]
#   [  3 321]]
#
#  [[608   4]
#   [  2 332]]
#
#  [[718   0]
#   [  2 226]]
#
#  [[246   3]
#   [ 11 686]]
#
#  [[ 79   0]
#   [  5 862]]
#
#  [[739   1]
#   [  5 201]]]
#
#
#
#
# ********** Random Seed: 98 **********
#
#
# Evaluating Label Powerset
# Accuracy: 0.9841437632135307
# Macro F1 Score: 0.992425502377678
# Weighted F1 score: 0.9947450696185004
# Micro F1 score: 0.9947470817120623
# Macro Precision: 0.9915429618104713
# Weighted Precision: 0.9930134845817199
# Micro Precision: 0.9930083511361429
# Macro Recall: 0.993329341002805
# Weighted Recall: 0.9964919119080101
# Micro Recall: 0.9964919119080101
# Hamming Loss: 0.005189313857389967
# Zero One Loss: 0.015856236786469302
# Jaccard Similarity: 0.9891196013289036
# Classification Report:
#                       precision    recall  f1-score   support
#
#    Credential Access       0.99      1.00      1.00       273
#      Defence Evasion       0.99      1.00      1.00       820
#            Discovery       1.00      1.00      1.00       845
#            Execution       0.99      1.00      0.99       519
#       Initial Access       0.98      0.97      0.97        91
#          Persistance       0.99      1.00      0.99       297
#         Exfiltration       0.99      0.99      0.99       356
# Privilage Escalation       1.00      0.99      1.00       208
#  Command and control       1.00      1.00      1.00       688
#           Collection       0.99      1.00      1.00       856
# ...
#            Execution       0.99      0.99      0.99       571
#       Initial Access       0.98      1.00      0.99       129
#          Persistance       1.00      0.99      0.99       313
#         Exfiltration       0.99      0.99      0.99       441
# Privilage Escalation       1.00      1.00      1.00       211
#  Command and control       0.99      0.99      0.99       712
#           Collection       0.99      1.00      1.00       970
#               Impact       0.99      1.00      0.99       234
#
#            micro avg       0.99      0.99      0.99      5735
#            macro avg       0.99      0.99      0.99      5735
#         weighted avg       0.99      0.99      0.99      5735
#          samples avg       0.99      0.99      0.99      5735
#
# Multilabel Confusion Matrix:
# [[[777   4]
#   [  8 281]]
#
#  [[156   2]
#   [  6 906]]
#
#  [[112   5]
#   [  5 948]]
#
#  [[496   3]
#   [  4 567]]
#
#  [[939   2]
#   [  0 129]]
#
#  [[756   1]
#   [  3 310]]
#
#  [[626   3]
#   [  4 437]]
#
#  [[858   1]
#   [  1 210]]
#
#  [[351   7]
#   [  4 708]]
#
#  [[ 94   6]
#   [  3 967]]
#
#  [[833   3]
#   [  1 233]]]
#
#
#
#
# ********** Random Seed: 2396 **********
#
#
# Evaluating Label Powerset
# Accuracy: 0.983177570093458
# Macro F1 Score: 0.9936507363394514
# Weighted F1 score: 0.9948363841792176
# Micro F1 score: 0.9948385967981804
# Macro Precision: 0.9933927473444537
# Weighted Precision: 0.9944036708806424
# Micro Precision: 0.9944036376355369
# Macro Recall: 0.9939154096241315
# Weighted Recall: 0.995273936635743
# Micro Recall: 0.995273936635743
# Hamming Loss: 0.005012744265080714
# Zero One Loss: 0.016822429906542036
# Jaccard Similarity: 0.9899054294615043
# Classification Report:
#                       precision    recall  f1-score   support
#
#    Credential Access       0.99      0.99      0.99       296
#      Defence Evasion       1.00      0.99      1.00       907
#            Discovery       0.99      1.00      1.00       970
#            Execution       0.99      1.00      1.00       564
#       Initial Access       1.00      1.00      1.00       145
#          Persistance       0.99      1.00      1.00       307
#         Exfiltration       1.00      1.00      1.00       418
# Privilage Escalation       0.98      0.98      0.98       198
#  Command and control       0.99      1.00      1.00       715
#           Collection       1.00      1.00      1.00       967
#               Impact       0.99      0.98      0.99       226
#
#            micro avg       0.99      1.00      0.99      5713
#            macro avg       0.99      0.99      0.99      5713
#         weighted avg       0.99      1.00      0.99      5713
#          samples avg       0.99      0.99      0.99      5713
#
# Multilabel Confusion Matrix:
# [[[770   4]
#   [  4 292]]
#
#  [[160   3]
#   [  5 902]]
#
#  [[ 95   5]
#   [  4 966]]
#
#  [[503   3]
#   [  1 563]]
#
#  [[925   0]
#   [  0 145]]
#
#  [[761   2]
#   [  1 306]]
#
#  [[650   2]
#   [  0 418]]
#
#  [[869   3]
#   [  3 195]]
#
#  [[350   5]
#   [  2 713]]
#
#  [[100   3]
#   [  3 964]]
#
#  [[842   2]
#   [  4 222]]]
#
#
#
#
# ********** Random Seed: 451 **********
#
#
# Evaluating Label Powerset
# Accuracy: 0.9738317757009346
# Macro F1 Score: 0.9912770824974655
# Weighted F1 score: 0.9935991556285337
# Micro F1 score: 0.9935948056506098
# Macro Precision: 0.9900257076219326
# Weighted Precision: 0.9924834259634373
# Micro Precision: 0.9924627519719544
# Macro Recall: 0.9925471673036056
# Weighted Recall: 0.9947294448348559
# Micro Recall: 0.9947294448348559
# Hamming Loss: 0.0062022090059473236
# Zero One Loss: 0.0261682242990654
# Jaccard Similarity: 0.9854684023141967
# Classification Report:
#                       precision    recall  f1-score   support
#
#    Credential Access       0.99      0.98      0.99       278
#      Defence Evasion       1.00      1.00      1.00       895
#            Discovery       1.00      1.00      1.00       954
#            Execution       0.98      0.99      0.99       531
#       Initial Access       0.99      0.99      0.99       144
#          Persistance       0.99      1.00      0.99       334
#         Exfiltration       0.99      0.99      0.99       428
# Privilage Escalation       0.99      0.99      0.99       214
#  Command and control       0.99      1.00      1.00       726
#           Collection       1.00      1.00      1.00       947
#               Impact       0.97      0.98      0.98       241
#
#            micro avg       0.99      0.99      0.99      5692
#            macro avg       0.99      0.99      0.99      5692
#         weighted avg       0.99      0.99      0.99      5692
#          samples avg       0.99      0.99      0.99      5692
#
# Multilabel Confusion Matrix:
# [[[789   3]
#   [  5 273]]
#
#  [[172   3]
#   [  4 891]]
#
#  [[112   4]
#   [  3 951]]
#
#  [[530   9]
#   [  3 528]]
#
#  [[925   1]
#   [  1 143]]
#
#  [[733   3]
#   [  1 333]]
#
#  [[639   3]
#   [  3 425]]
#
#  [[853   3]
#   [  3 211]]
#
#  [[339   5]
#   [  0 726]]
#
#  [[121   2]
#   [  3 944]]
#
#  [[822   7]
#   [  4 237]]]
#
#
#
#
# ********** Random Seed: 995 **********
#
#
# Evaluating Label Powerset
# Accuracy: 0.9822429906542056
# Macro F1 Score: 0.9928136720640522
# Weighted F1 score: 0.9938180017700161
# Micro F1 score: 0.9938234014789039
# Macro Precision: 0.9935182035903459
# Weighted Precision: 0.9944352289966074
# Micro Precision: 0.9944289693593314
# Macro Recall: 0.992135651599396
# Weighted Recall: 0.9932185706833594
# Micro Recall: 0.9932185706833594
# Hamming Loss: 0.006032285471537808
# Zero One Loss: 0.017757009345794383
# Jaccard Similarity: 0.9879728526924788
# Classification Report:
#                       precision    recall  f1-score   support
#
#    Credential Access       0.99      0.97      0.98       276
#      Defence Evasion       1.00      0.99      1.00       910
#            Discovery       0.99      0.99      0.99       955
#            Execution       0.99      1.00      1.00       575
#       Initial Access       1.00      1.00      1.00       138
#          Persistance       0.99      1.00      0.99       326
#         Exfiltration       0.99      1.00      0.99       410
# Privilage Escalation       0.99      0.99      0.99       229
#  Command and control       0.99      1.00      0.99       725
#           Collection       1.00      0.99      0.99       976
#               Impact       0.99      0.98      0.98       231
#
#            micro avg       0.99      0.99      0.99      5751
#            macro avg       0.99      0.99      0.99      5751
#         weighted avg       0.99      0.99      0.99      5751
#          samples avg       0.99      0.99      0.99      5751
#
# Multilabel Confusion Matrix:
# [[[792   2]
#   [  7 269]]
#
#  [[157   3]
#   [  5 905]]
#
#  [[110   5]
#   [  6 949]]
#
#  [[492   3]
#   [  1 574]]
#
#  [[932   0]
#   [  0 138]]
#
#  [[740   4]
#   [  0 326]]
#
#  [[657   3]
#   [  2 408]]
#
#  [[839   2]
#   [  3 226]]
#
#  [[340   5]
#   [  3 722]]
#
#  [[ 92   2]
#   [  8 968]]
#
#  [[836   3]
#   [  4 227]]]
#
#
#
#
# ********** Random Seed: 98 **********
#
#
# Evaluating Label Powerset
# Accuracy: 0.983177570093458
# Macro F1 Score: 0.9922653755113309
# Weighted F1 score: 0.9939468524074669
# Micro F1 score: 0.9939500219202104
# Macro Precision: 0.9930954702179178
# Weighted Precision: 0.9945642856360228
# Micro Precision: 0.9945604492016143
# Macro Recall: 0.991451737133
# Weighted Recall: 0.9933403434980722
# Micro Recall: 0.9933403434980722
# Hamming Loss: 0.0058623619371282925
# Zero One Loss: 0.016822429906542036
# Jaccard Similarity: 0.9893139000148345
# Classification Report:
#                       precision    recall  f1-score   support
#
#    Credential Access       0.99      0.98      0.98       286
#      Defence Evasion       1.00      1.00      1.00       901
#            Discovery       1.00      1.00      1.00       957
#            Execution       0.99      0.99      0.99       562
#       Initial Access       0.99      0.99      0.99       130
#          Persistance       1.00      0.99      0.99       314
#         Exfiltration       0.99      1.00      1.00       420
# Privilage Escalation       1.00      0.99      0.99       217
#  Command and control       0.99      0.99      0.99       733
#           Collection       1.00      1.00      1.00       964
#               Impact       0.98      0.99      0.98       222
#
#            micro avg       0.99      0.99      0.99      5706
#            macro avg       0.99      0.99      0.99      5706
#         weighted avg       0.99      0.99      0.99      5706
#          samples avg       0.99      0.99      0.99      5706
#
# Multilabel Confusion Matrix:
# [[[781   3]
#   [  6 280]]
#
#  [[167   2]
#   [  3 898]]
#
#  [[111   2]
#   [  3 954]]
#
#  [[504   4]
#   [  7 555]]
#
#  [[939   1]
#   [  1 129]]
#
#  [[755   1]
#   [  4 310]]
#
#  [[646   4]
#   [  0 420]]
#
#  [[852   1]
#   [  2 215]]
#
#  [[332   5]
#   [  5 728]]
#
#  [[102   4]
#   [  4 960]]
#
#  [[844   4]
#   [  3 219]]]
#
#
#
#
# ********** Random Seed: 262 **********
#
#
# Evaluating Label Powerset
# Accuracy: 0.9794392523364486
# Macro F1 Score: 0.9922798080856395
# Weighted F1 score: 0.9943153248813187
# Micro F1 score: 0.994316691440063
# Macro Precision: 0.9908688310907025
# Weighted Precision: 0.9930213579315387
# Micro Precision: 0.9930143206426825
# Macro Recall: 0.9937197686249832
# Weighted Recall: 0.9956224829276834
# Micro Recall: 0.9956224829276834
# Hamming Loss: 0.0055225148683092605
# Zero One Loss: 0.020560747663551426
# Jaccard Similarity: 0.9893669336893637
# Classification Report:
#                       precision    recall  f1-score   support
#
#    Credential Access       0.98      0.98      0.98       286
#      Defence Evasion       1.00      1.00      1.00       909
#            Discovery       0.99      1.00      1.00       943
#            Execution       0.99      1.00      1.00       573
#       Initial Access       0.98      1.00      0.99       134
#          Persistance       0.99      0.99      0.99       317
#         Exfiltration       0.99      1.00      0.99       435
# Privilage Escalation       0.99      0.99      0.99       220
#  Command and control       0.99      1.00      0.99       713
#           Collection       1.00      1.00      1.00       960
#               Impact       0.99      0.99      0.99       221
#
#            micro avg       0.99      1.00      0.99      5711
#            macro avg       0.99      0.99      0.99      5711
#         weighted avg       0.99      1.00      0.99      5711
#          samples avg       0.99      0.99      0.99      5711
#
# Multilabel Confusion Matrix:
# [[[779   5]
#   [  5 281]]
#
#  [[158   3]
#   [  3 906]]
#
#  [[121   6]
#   [  1 942]]
#
#  [[494   3]
#   [  2 571]]
#
#  [[933   3]
#   [  0 134]]
#
#  [[751   2]
#   [  4 313]]
#
#  [[631   4]
#   [  2 433]]
#
#  [[848   2]
#   [  3 217]]
#
#  [[351   6]
#   [  2 711]]
#
#  [[106   4]
#   [  1 959]]
#
#  [[847   2]
#   [  2 219]]]
#
#
#
#
# ********** Random Seed: 354 **********
#
#
# Evaluating Label Powerset
# Accuracy: 0.9822429906542056
# Macro F1 Score: 0.9934633195958209
# Weighted F1 score: 0.9947729635260547
# Micro F1 score: 0.9947787383377558
# Macro Precision: 0.993179423488186
# Weighted Precision: 0.9938532458326881
# Micro Precision: 0.9938429964084146
# Macro Recall: 0.9937883359216627
# Weighted Recall: 0.9957162440027416
# Micro Recall: 0.9957162440027416
# Hamming Loss: 0.005182667799490229
# Zero One Loss: 0.017757009345794383
# Jaccard Similarity: 0.9910947930574099
# Classification Report:
#                       precision    recall  f1-score   support
#
#    Credential Access       0.99      0.99      0.99       317
#      Defence Evasion       1.00      1.00      1.00       923
#            Discovery       0.99      1.00      1.00       954
#            Execution       0.99      0.99      0.99       569
#       Initial Access       1.00      1.00      1.00       123
#          Persistance       0.99      0.99      0.99       334
#         Exfiltration       0.99      1.00      0.99       442
# Privilage Escalation       0.98      1.00      0.99       228
#  Command and control       0.99      0.99      0.99       747
#           Collection       0.99      1.00      1.00       976
#               Impact       1.00      0.97      0.98       223
#
#            micro avg       0.99      1.00      0.99      5836
#            macro avg       0.99      0.99      0.99      5836
#         weighted avg       0.99      1.00      0.99      5836
#          samples avg       0.99      0.99      0.99      5836
#
# Multilabel Confusion Matrix:
# [[[751   2]
#   [  4 313]]
#
#  [[145   2]
#   [  1 922]]
#
#  [[111   5]
#   [  1 953]]
#
#  [[496   5]
#   [  3 566]]
#
#  [[947   0]
#   [  0 123]]
#
#  [[733   3]
#   [  3 331]]
#
#  [[623   5]
#   [  0 442]]
#
#  [[838   4]
#   [  1 227]]
#
#  [[319   4]
#   [  6 741]]
#
#  [[ 89   5]
#   [  0 976]]
#
#  [[846   1]
#   [  6 217]]]
#
#
#
#
# ********** Random Seed: 560 **********
#
#
# Evaluating Label Powerset
# Accuracy: 0.9775700934579439
# Macro F1 Score: 0.9912808652797566
# Weighted F1 score: 0.9930017727660283
# Micro F1 score: 0.9929910636060978
# Macro Precision: 0.9877016971909414
# Weighted Precision: 0.9909506922138818
# Micro Precision: 0.990907501311418
# Macro Recall: 0.9949183040816895
# Weighted Recall: 0.9950834064969272
# Micro Recall: 0.9950834064969272
# Hamming Loss: 0.006796941376380629
# Zero One Loss: 0.02242990654205612
# Jaccard Similarity: 0.9856601394451862
# Classification Report:
#                       precision    recall  f1-score   support
#
#    Credential Access       0.97      1.00      0.98       279
#      Defence Evasion       1.00      1.00      1.00       910
#            Discovery       0.99      0.99      0.99       963
#            Execution       0.99      0.99      0.99       539
#       Initial Access       0.99      1.00      0.99       152
#          Persistance       0.98      1.00      0.99       290
#         Exfiltration       1.00      1.00      1.00       446
# Privilage Escalation       0.99      1.00      0.99       205
#  Command and control       0.99      1.00      0.99       709
#           Collection       0.99      1.00      1.00       964
#               Impact       0.97      0.98      0.97       238
#
#            micro avg       0.99      1.00      0.99      5695
#            macro avg       0.99      0.99      0.99      5695
#         weighted avg       0.99      1.00      0.99      5695
#          samples avg       0.99      0.99      0.99      5695
#
# Multilabel Confusion Matrix:
# [[[783   8]
#   [  1 278]]
#
#  [[156   4]
#   [  4 906]]
#
#  [[100   7]
#   [  6 957]]
#
#  [[528   3]
#   [  4 535]]
#
#  [[916   2]
#   [  0 152]]
#
#  [[775   5]
#   [  0 290]]
#
#  [[623   1]
#   [  0 446]]
#
#  [[863   2]
#   [  1 204]]
#
#  [[354   7]
#   [  3 706]]
#
#  [[101   5]
#   [  4 960]]
#
#  [[824   8]
#   [  5 233]]]
#
#
#
#
# ********** Random Seed: 1600 **********
#
#
# Evaluating Label Powerset
# Accuracy: 0.991588785046729
# Macro F1 Score: 0.99630960961733
# Weighted F1 score: 0.996679357494221
# Micro F1 score: 0.9966812227074235
# Macro Precision: 0.9951874881927423
# Weighted Precision: 0.9949483973313656
# Micro Precision: 0.9949433304272014
# Macro Recall: 0.9974499973361418
# Weighted Recall: 0.9984251968503937
# Micro Recall: 0.9984251968503937
# Hamming Loss: 0.0032285471537807984
# Zero One Loss: 0.008411214953271018
# Jaccard Similarity: 0.9934579439252337
# Classification Report:
#                       precision    recall  f1-score   support
#
#    Credential Access       1.00      1.00      1.00       294
#      Defence Evasion       0.99      1.00      1.00       904
#            Discovery       1.00      1.00      1.00       950
#            Execution       0.99      1.00      1.00       552
#       Initial Access       1.00      1.00      1.00       135
#          Persistance       0.99      1.00      1.00       319
#         Exfiltration       1.00      1.00      1.00       429
# Privilage Escalation       1.00      1.00      1.00       212
#  Command and control       1.00      1.00      1.00       723
#           Collection       0.99      1.00      1.00       957
#               Impact       1.00      0.98      0.99       240
#
#            micro avg       0.99      1.00      1.00      5715
#            macro avg       1.00      1.00      1.00      5715
#         weighted avg       0.99      1.00      1.00      5715
#          samples avg       0.99      1.00      0.99      5715
#
# Multilabel Confusion Matrix:
# [[[775   1]
#   [  1 293]]
#
#  [[161   5]
#   [  2 902]]
#
#  [[116   4]
#   [  1 949]]
#
#  [[513   5]
#   [  0 552]]
#
#  [[935   0]
#   [  0 135]]
#
#  [[748   3]
#   [  0 319]]
#
#  [[639   2]
#   [  0 429]]
#
#  [[857   1]
#   [  1 211]]
#
#  [[345   2]
#   [  0 723]]
#
#  [[108   5]
#   [  0 957]]
#
#  [[829   1]
#   [  4 236]]]
